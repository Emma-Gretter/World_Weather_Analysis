# %%
import random
import numpy as np
from datetime import datetime 
import requests
from citipy import citipy
from config import weather_api_key

# %%
# generate 2000 random lat and lng
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-90.00, 90.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# turn zip into list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# basic URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1  
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Description": city_description,
            "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longyearbyen
# Processing Record 2 of Set 1 | mitu
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | chingola
# Processing Record 5 of Set 1 | limbe
# Processing Record 6 of Set 1 | tessalit
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | valparaiso
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | vila franca do campo
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 1 | giyon
# Processing Record 15 of Set 1 | nogent-le-rotrou
# Processing Record 16 of Set 1 | shieli
# Processing Record 17 of Set 1 | bathsheba
# Processing Record 18 of Set 1 | ponta do sol
# Processing Record 19 of Set 1 | quelimane
# Processing Record 20 of Set 1 | vestmannaeyjar
# Processing Record 21 of Set 1 | bababe
# City not found. Skipping...
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | santa rosa
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | shahr-e babak
# Processing Record 26 of Set 1 | touros
# Processing Record 27 of Set 1 | mar del plata
# Processing Record 28 of Set 1 | bonthe
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | blagoyevo
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | orjahovo
# City not found. Skipping...
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | chalinze
# Processing Record 36 of Set 1 | saint-pierre
# Processing Record 37 of Set 1 | sikasso
# Processing Record 38 of Set 1 | axim
# Processing Record 39 of Set 1 | praia da vitoria
# Processing Record 40 of Set 1 | malangali
# Processing Record 41 of Set 1 | exmouth
# Processing Record 42 of Set 1 | scarborough
# Processing Record 43 of Set 1 | sao filipe
# Processing Record 44 of Set 1 | pyshchug
# Processing Record 45 of Set 1 | salalah
# Processing Record 46 of Set 1 | dingle
# Processing Record 47 of Set 1 | castro
# Processing Record 48 of Set 1 | osorno
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | bolanos de calatrava
# Processing Record 1 of Set 2 | trairi
# Processing Record 2 of Set 2 | constitucion
# Processing Record 3 of Set 2 | bengkulu
# Processing Record 4 of Set 2 | jalu
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | adrar
# Processing Record 7 of Set 2 | los llanos de aridane
# Processing Record 8 of Set 2 | gloucester
# Processing Record 9 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 2 | kirkwall
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | wattegama
# Processing Record 13 of Set 2 | posse
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | cayenne
# Processing Record 16 of Set 2 | ilhabela
# Processing Record 17 of Set 2 | kruisfontein
# Processing Record 18 of Set 2 | san rafael
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | nanortalik
# Processing Record 21 of Set 2 | bereda
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | murowana goslina
# Processing Record 24 of Set 2 | djibo
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | raudeberg
# Processing Record 27 of Set 2 | sambava
# Processing Record 28 of Set 2 | rudbar
# Processing Record 29 of Set 2 | saint-philippe
# Processing Record 30 of Set 2 | kampene
# Processing Record 31 of Set 2 | marsaxlokk
# Processing Record 32 of Set 2 | chuy
# Processing Record 33 of Set 2 | storforshei
# Processing Record 34 of Set 2 | borovoy
# Processing Record 35 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 2 | ahar
# Processing Record 37 of Set 2 | pastavy
# Processing Record 38 of Set 2 | lincoln village
# Processing Record 39 of Set 2 | takoradi
# Processing Record 40 of Set 2 | tasiilaq
# Processing Record 41 of Set 2 | coquimbo
# Processing Record 42 of Set 2 | nador
# Processing Record 43 of Set 2 | viedma
# Processing Record 44 of Set 2 | husavik
# Processing Record 45 of Set 2 | carutapera
# Processing Record 46 of Set 2 | iskateley
# Processing Record 47 of Set 2 | ilulissat
# Processing Record 48 of Set 2 | mahebourg
# Processing Record 49 of Set 2 | gat
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | souillac
# Processing Record 2 of Set 3 | iqaluit
# Processing Record 3 of Set 3 | misratah
# Processing Record 4 of Set 3 | batsfjord
# Processing Record 5 of Set 3 | lyuban
# Processing Record 6 of Set 3 | east london
# Processing Record 7 of Set 3 | beaufort
# Processing Record 8 of Set 3 | herat
# Processing Record 9 of Set 3 | barcelos
# Processing Record 10 of Set 3 | vila velha
# Processing Record 11 of Set 3 | belmonte
# Processing Record 12 of Set 3 | la baule-escoublac
# Processing Record 13 of Set 3 | ribeira grande
# Processing Record 14 of Set 3 | karaman
# Processing Record 15 of Set 3 | ipameri
# Processing Record 16 of Set 3 | shibarghan
# City not found. Skipping...
# Processing Record 17 of Set 3 | saint-augustin
# Processing Record 18 of Set 3 | grand gaube
# Processing Record 19 of Set 3 | moose factory
# Processing Record 20 of Set 3 | kudahuvadhoo
# Processing Record 21 of Set 3 | qasigiannguit
# Processing Record 22 of Set 3 | carndonagh
# Processing Record 23 of Set 3 | maraa
# Processing Record 24 of Set 3 | huicungo
# Processing Record 25 of Set 3 | maracacume
# Processing Record 26 of Set 3 | saint-francois
# Processing Record 27 of Set 3 | paamiut
# Processing Record 28 of Set 3 | mastung
# Processing Record 29 of Set 3 | marsh harbour
# Processing Record 30 of Set 3 | kathu
# Processing Record 31 of Set 3 | maloy
# Processing Record 32 of Set 3 | zwedru
# Processing Record 33 of Set 3 | sokoto
# Processing Record 34 of Set 3 | araouane
# Processing Record 35 of Set 3 | richards bay
# Processing Record 36 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 3 | pitimbu
# Processing Record 38 of Set 3 | lagoa
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | krasnoselkup
# Processing Record 41 of Set 3 | oranjemund
# Processing Record 42 of Set 3 | otkaznoye
# Processing Record 43 of Set 3 | birin
# Processing Record 44 of Set 3 | ammapettai
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | hvammstangi
# City not found. Skipping...
# Processing Record 47 of Set 3 | likhoslavl
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 3 | kosh-agach
# Processing Record 1 of Set 4 | coihaique
# Processing Record 2 of Set 4 | carnarvon
# Processing Record 3 of Set 4 | jorpeland
# Processing Record 4 of Set 4 | cockburn town
# Processing Record 5 of Set 4 | balkanabat
# Processing Record 6 of Set 4 | san juan
# Processing Record 7 of Set 4 | kyrksaeterora
# Processing Record 8 of Set 4 | albany
# Processing Record 9 of Set 4 | clyde river
# Processing Record 10 of Set 4 | pangnirtung
# Processing Record 11 of Set 4 | neyshabur
# Processing Record 12 of Set 4 | skibbereen
# Processing Record 13 of Set 4 | conceicao do araguaia
# Processing Record 14 of Set 4 | ambilobe
# Processing Record 15 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 4 | bonavista
# Processing Record 17 of Set 4 | klaksvik
# Processing Record 18 of Set 4 | toamasina
# Processing Record 19 of Set 4 | tazovskiy
# Processing Record 20 of Set 4 | kavaratti
# Processing Record 21 of Set 4 | cubuk
# Processing Record 22 of Set 4 | pancas
# Processing Record 23 of Set 4 | ancud
# Processing Record 24 of Set 4 | muros
# Processing Record 25 of Set 4 | teofilo otoni
# Processing Record 26 of Set 4 | nkoteng
# Processing Record 27 of Set 4 | saint george
# Processing Record 28 of Set 4 | florianopolis
# Processing Record 29 of Set 4 | saint-louis
# Processing Record 30 of Set 4 | havoysund
# Processing Record 31 of Set 4 | namibe
# Processing Record 32 of Set 4 | wegorzewo
# Processing Record 33 of Set 4 | sakakah
# Processing Record 34 of Set 4 | kevsala
# Processing Record 35 of Set 4 | rovaniemi
# Processing Record 36 of Set 4 | sistranda
# Processing Record 37 of Set 4 | mindyak
# Processing Record 38 of Set 4 | okandja
# City not found. Skipping...
# Processing Record 39 of Set 4 | nisia floresta
# Processing Record 40 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 4 | caravelas
# Processing Record 42 of Set 4 | gamba
# Processing Record 43 of Set 4 | goundam
# Processing Record 44 of Set 4 | marawi
# Processing Record 45 of Set 4 | santa maria da vitoria
# Processing Record 46 of Set 4 | abu dhabi
# Processing Record 47 of Set 4 | waddan
# Processing Record 48 of Set 4 | lebu
# Processing Record 49 of Set 4 | uribia
# Processing Record 50 of Set 4 | puerto maldonado
# Processing Record 1 of Set 5 | opuwo
# Processing Record 2 of Set 5 | thunder bay
# Processing Record 3 of Set 5 | monrovia
# Processing Record 4 of Set 5 | privokzalnyy
# City not found. Skipping...
# Processing Record 5 of Set 5 | sabzevar
# Processing Record 6 of Set 5 | bejucal
# Processing Record 7 of Set 5 | pisco
# Processing Record 8 of Set 5 | penzance
# Processing Record 9 of Set 5 | taltal
# Processing Record 10 of Set 5 | miraflores
# Processing Record 11 of Set 5 | sandanski
# Processing Record 12 of Set 5 | villa del rosario
# Processing Record 13 of Set 5 | mitsamiouli
# Processing Record 14 of Set 5 | tiznit
# Processing Record 15 of Set 5 | manchester
# Processing Record 16 of Set 5 | diamantino
# Processing Record 17 of Set 5 | suoyarvi
# Processing Record 18 of Set 5 | badin
# Processing Record 19 of Set 5 | pasni
# Processing Record 20 of Set 5 | victoria
# Processing Record 21 of Set 5 | rosetta
# Processing Record 22 of Set 5 | synya
# Processing Record 23 of Set 5 | tashara
# Processing Record 24 of Set 5 | sokoni
# Processing Record 25 of Set 5 | saint-claude
# Processing Record 26 of Set 5 | havelock
# Processing Record 27 of Set 5 | back mountain
# Processing Record 28 of Set 5 | teya
# Processing Record 29 of Set 5 | chabahar
# Processing Record 30 of Set 5 | harper
# Processing Record 31 of Set 5 | standerton
# Processing Record 32 of Set 5 | mmabatho
# Processing Record 33 of Set 5 | maragogi
# Processing Record 34 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 5 | douentza
# Processing Record 36 of Set 5 | tricase
# Processing Record 37 of Set 5 | linhares
# Processing Record 38 of Set 5 | gedo
# Processing Record 39 of Set 5 | kamenka
# Processing Record 40 of Set 5 | khuldabad
# Processing Record 41 of Set 5 | olafsvik
# Processing Record 42 of Set 5 | gobabis
# Processing Record 43 of Set 5 | bhind
# Processing Record 44 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 5 | highland springs
# Processing Record 46 of Set 5 | gouyave
# Processing Record 47 of Set 5 | oromocto
# Processing Record 48 of Set 5 | micheweni
# Processing Record 49 of Set 5 | panaba
# Processing Record 50 of Set 5 | bandarbeyla
# Processing Record 1 of Set 6 | kitob
# Processing Record 2 of Set 6 | muscat
# Processing Record 3 of Set 6 | rancho veloz
# Processing Record 4 of Set 6 | caetite
# Processing Record 5 of Set 6 | lamu
# Processing Record 6 of Set 6 | laguna
# Processing Record 7 of Set 6 | outjo
# Processing Record 8 of Set 6 | vardo
# Processing Record 9 of Set 6 | uusikaupunki
# Processing Record 10 of Set 6 | careiro da varzea
# Processing Record 11 of Set 6 | maykor
# Processing Record 12 of Set 6 | kharitonovo
# Processing Record 13 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 6 | aquiraz
# Processing Record 15 of Set 6 | faranah
# Processing Record 16 of Set 6 | santa cruz cabralia
# Processing Record 17 of Set 6 | mao
# Processing Record 18 of Set 6 | guiratinga
# Processing Record 19 of Set 6 | hamilton
# Processing Record 20 of Set 6 | hobyo
# Processing Record 21 of Set 6 | matay
# Processing Record 22 of Set 6 | nynashamn
# Processing Record 23 of Set 6 | puri
# Processing Record 24 of Set 6 | emba
# Processing Record 25 of Set 6 | uzumlu
# City not found. Skipping...
# Processing Record 26 of Set 6 | turayf
# Processing Record 27 of Set 6 | roald
# Processing Record 28 of Set 6 | buta
# Processing Record 29 of Set 6 | westport
# Processing Record 30 of Set 6 | bin qirdan
# Processing Record 31 of Set 6 | kigorobya
# Processing Record 32 of Set 6 | le port
# Processing Record 33 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 34 of Set 6 | soto
# Processing Record 35 of Set 6 | ewo
# Processing Record 36 of Set 6 | trelew
# Processing Record 37 of Set 6 | saldanha
# Processing Record 38 of Set 6 | port blair
# Processing Record 39 of Set 6 | chamba
# Processing Record 40 of Set 6 | watsa
# Processing Record 41 of Set 6 | rio gallegos
# Processing Record 42 of Set 6 | los angeles
# Processing Record 43 of Set 6 | dolzhanskaya
# Processing Record 44 of Set 6 | rey bouba
# Processing Record 45 of Set 6 | lumberton
# Processing Record 46 of Set 6 | onega
# Processing Record 47 of Set 6 | nicoya
# Processing Record 48 of Set 6 | salacgriva
# Processing Record 49 of Set 6 | hun
# Processing Record 50 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 1 of Set 7 | dzilam gonzalez
# Processing Record 2 of Set 7 | petropavlovskoye
# Processing Record 3 of Set 7 | wadi musa
# Processing Record 4 of Set 7 | nizhniy odes
# Processing Record 5 of Set 7 | san cristobal
# Processing Record 6 of Set 7 | cabedelo
# Processing Record 7 of Set 7 | abha
# Processing Record 8 of Set 7 | hualmay
# Processing Record 9 of Set 7 | ostrovnoy
# Processing Record 10 of Set 7 | oussouye
# Processing Record 11 of Set 7 | henties bay
# Processing Record 12 of Set 7 | havre-saint-pierre
# Processing Record 13 of Set 7 | bay roberts
# Processing Record 14 of Set 7 | chapada dos guimaraes
# Processing Record 15 of Set 7 | san pedro
# Processing Record 16 of Set 7 | sajanan
# Processing Record 17 of Set 7 | parrsboro
# Processing Record 18 of Set 7 | maldonado
# Processing Record 19 of Set 7 | rapar
# Processing Record 20 of Set 7 | nouadhibou
# Processing Record 21 of Set 7 | esteli
# Processing Record 22 of Set 7 | chirnogi
# Processing Record 23 of Set 7 | henderson
# Processing Record 24 of Set 7 | talcahuano
# Processing Record 25 of Set 7 | bubanza
# Processing Record 26 of Set 7 | shakawe
# Processing Record 27 of Set 7 | manta
# Processing Record 28 of Set 7 | amurrio
# Processing Record 29 of Set 7 | yar-sale
# Processing Record 30 of Set 7 | kutum
# Processing Record 31 of Set 7 | stromness
# Processing Record 32 of Set 7 | grand-santi
# Processing Record 33 of Set 7 | vigrestad
# Processing Record 34 of Set 7 | sukhumi
# Processing Record 35 of Set 7 | sao joao da barra
# Processing Record 36 of Set 7 | porto murtinho
# Processing Record 37 of Set 7 | betsiamites
# Processing Record 38 of Set 7 | jubayl
# City not found. Skipping...
# Processing Record 39 of Set 7 | bria
# Processing Record 40 of Set 7 | masvingo
# Processing Record 41 of Set 7 | dungarvan
# Processing Record 42 of Set 7 | shelomi
# Processing Record 43 of Set 7 | sarankhola
# Processing Record 44 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 45 of Set 7 | mikumi
# Processing Record 46 of Set 7 | jacmel
# Processing Record 47 of Set 7 | kombissiri
# Processing Record 48 of Set 7 | san rafael del sur
# Processing Record 49 of Set 7 | durham
# Processing Record 50 of Set 7 | barra do garcas
# Processing Record 1 of Set 8 | mhlambanyatsi
# Processing Record 2 of Set 8 | cidreira
# Processing Record 3 of Set 8 | port-gentil
# Processing Record 4 of Set 8 | porto santo
# Processing Record 5 of Set 8 | puerto asis
# Processing Record 6 of Set 8 | mehamn
# Processing Record 7 of Set 8 | rio grande
# Processing Record 8 of Set 8 | jacareacanga
# Processing Record 9 of Set 8 | stepnyak
# Processing Record 10 of Set 8 | sharhorod
# Processing Record 11 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 12 of Set 8 | marystown
# Processing Record 13 of Set 8 | inirida
# Processing Record 14 of Set 8 | lasa
# Processing Record 15 of Set 8 | houma
# Processing Record 16 of Set 8 | blagodatnoye
# Processing Record 17 of Set 8 | mugumu
# Processing Record 18 of Set 8 | contamana
# Processing Record 19 of Set 8 | macherla
# Processing Record 20 of Set 8 | talnakh
# Processing Record 21 of Set 8 | chapais
# Processing Record 22 of Set 8 | codrington
# Processing Record 23 of Set 8 | banda aceh
# Processing Record 24 of Set 8 | saint anthony
# Processing Record 25 of Set 8 | beroroha
# Processing Record 26 of Set 8 | marzuq
# Processing Record 27 of Set 8 | olinda
# Processing Record 28 of Set 8 | foumban
# Processing Record 29 of Set 8 | durban
# Processing Record 30 of Set 8 | kollumerland
# City not found. Skipping...
# Processing Record 31 of Set 8 | port hawkesbury
# Processing Record 32 of Set 8 | lago da pedra
# Processing Record 33 of Set 8 | odweyne
# Processing Record 34 of Set 8 | ismailia
# Processing Record 35 of Set 8 | dutlwe
# Processing Record 36 of Set 8 | funtua
# Processing Record 37 of Set 8 | grindavik
# Processing Record 38 of Set 8 | vasylivka
# Processing Record 39 of Set 8 | margate
# Processing Record 40 of Set 8 | hambantota
# Processing Record 41 of Set 8 | bhinga
# Processing Record 42 of Set 8 | paragominas
# Processing Record 43 of Set 8 | itabaianinha
# Processing Record 44 of Set 8 | necochea
# Processing Record 45 of Set 8 | cap malheureux
# Processing Record 46 of Set 8 | ravar
# Processing Record 47 of Set 8 | colmenar viejo
# Processing Record 48 of Set 8 | sadri
# Processing Record 49 of Set 8 | am timan
# Processing Record 50 of Set 8 | puerto cabezas
# Processing Record 1 of Set 9 | agadir
# Processing Record 2 of Set 9 | cobija
# Processing Record 3 of Set 9 | port-cartier
# Processing Record 4 of Set 9 | formello
# Processing Record 5 of Set 9 | sur
# Processing Record 6 of Set 9 | bilma
# Processing Record 7 of Set 9 | mogadishu
# Processing Record 8 of Set 9 | nantucket
# Processing Record 9 of Set 9 | alenquer
# Processing Record 10 of Set 9 | ust-tsilma
# Processing Record 11 of Set 9 | matagami
# Processing Record 12 of Set 9 | greaca
# Processing Record 13 of Set 9 | kautokeino
# Processing Record 14 of Set 9 | savannah bight
# Processing Record 15 of Set 9 | rundu
# Processing Record 16 of Set 9 | certegui
# Processing Record 17 of Set 9 | garowe
# Processing Record 18 of Set 9 | benghazi
# Processing Record 19 of Set 9 | camacha
# Processing Record 20 of Set 9 | general roca
# Processing Record 21 of Set 9 | nampula
# Processing Record 22 of Set 9 | berlevag
# Processing Record 23 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 24 of Set 9 | keetmanshoop
# Processing Record 25 of Set 9 | beruni
# City not found. Skipping...
# Processing Record 26 of Set 9 | bozoum
# Processing Record 27 of Set 9 | la palma
# Processing Record 28 of Set 9 | amarante do maranhao
# Processing Record 29 of Set 9 | dutse
# Processing Record 30 of Set 9 | ripky
# Processing Record 31 of Set 9 | nuuk
# Processing Record 32 of Set 9 | gerash
# Processing Record 33 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 9 | inhambane
# Processing Record 35 of Set 9 | berdsk
# Processing Record 36 of Set 9 | yarada
# Processing Record 37 of Set 9 | cheremukhovo
# Processing Record 38 of Set 9 | lethem
# Processing Record 39 of Set 9 | tocopilla
# Processing Record 40 of Set 9 | dwarka
# Processing Record 41 of Set 9 | sumbe
# Processing Record 42 of Set 9 | rio cuarto
# Processing Record 43 of Set 9 | carros
# Processing Record 44 of Set 9 | ferreira do alentejo
# Processing Record 45 of Set 9 | najran
# Processing Record 46 of Set 9 | remiremont
# Processing Record 47 of Set 9 | miranorte
# City not found. Skipping...
# Processing Record 48 of Set 9 | cambrils
# Processing Record 49 of Set 9 | puerto madryn
# Processing Record 50 of Set 9 | kotma
# Processing Record 1 of Set 10 | vesoul
# Processing Record 2 of Set 10 | chatsu
# City not found. Skipping...
# Processing Record 3 of Set 10 | korhogo
# Processing Record 4 of Set 10 | esmeraldas
# Processing Record 5 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 10 | mwinilunga
# Processing Record 7 of Set 10 | astana
# Processing Record 8 of Set 10 | tabou
# Processing Record 9 of Set 10 | ambikapur
# Processing Record 10 of Set 10 | hurghada
# Processing Record 11 of Set 10 | san carlos de bariloche
# Processing Record 12 of Set 10 | podosinovets
# Processing Record 13 of Set 10 | lalibela
# Processing Record 14 of Set 10 | geraldton
# Processing Record 15 of Set 10 | panjab
# Processing Record 16 of Set 10 | trinidad
# Processing Record 17 of Set 10 | rocha
# Processing Record 18 of Set 10 | jaunjelgava
# Processing Record 19 of Set 10 | rayagada
# Processing Record 20 of Set 10 | ust-kalmanka
# Processing Record 21 of Set 10 | uige
# Processing Record 22 of Set 10 | manoharpur
# Processing Record 23 of Set 10 | yenagoa
# Processing Record 24 of Set 10 | vertientes
# Processing Record 25 of Set 10 | coueron
# Processing Record 26 of Set 10 | sibut
# Processing Record 27 of Set 10 | andros town
# Processing Record 28 of Set 10 | mahibadhoo
# Processing Record 29 of Set 10 | boende
# Processing Record 30 of Set 10 | khash
# Processing Record 31 of Set 10 | kargil
# Processing Record 32 of Set 10 | lysa hora
# Processing Record 33 of Set 10 | puerto colombia
# Processing Record 34 of Set 10 | hofn
# Processing Record 35 of Set 10 | general delgado
# Processing Record 36 of Set 10 | zvenigovo
# Processing Record 37 of Set 10 | kaniama
# Processing Record 38 of Set 10 | visby
# Processing Record 39 of Set 10 | jumla
# Processing Record 40 of Set 10 | businga
# Processing Record 41 of Set 10 | salym
# Processing Record 42 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 10 | diffa
# Processing Record 44 of Set 10 | labrea
# Processing Record 45 of Set 10 | port perry
# Processing Record 46 of Set 10 | ericeira
# Processing Record 47 of Set 10 | ginir
# Processing Record 48 of Set 10 | porto novo
# Processing Record 49 of Set 10 | galle
# Processing Record 50 of Set 10 | warrington
# Processing Record 1 of Set 11 | madaoua
# Processing Record 2 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 11 | progreso
# Processing Record 4 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 5 of Set 11 | mabaruma
# Processing Record 6 of Set 11 | alghero
# Processing Record 7 of Set 11 | aksarka
# Processing Record 8 of Set 11 | benicarlo
# Processing Record 9 of Set 11 | bobo dioulasso
# Processing Record 10 of Set 11 | coruripe
# Processing Record 11 of Set 11 | tabory
# Processing Record 12 of Set 11 | moroni
# Processing Record 13 of Set 11 | the valley
# Processing Record 14 of Set 11 | quatre cocos
# Processing Record 15 of Set 11 | zholymbet
# Processing Record 16 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 17 of Set 11 | mubende
# Processing Record 18 of Set 11 | bud
# Processing Record 19 of Set 11 | vokhtoga
# Processing Record 20 of Set 11 | botelhos
# Processing Record 21 of Set 11 | miguel alves
# Processing Record 22 of Set 11 | krasnogvardeyskiy
# Processing Record 23 of Set 11 | mayumba
# Processing Record 24 of Set 11 | menongue
# Processing Record 25 of Set 11 | jaru
# Processing Record 26 of Set 11 | altay
# Processing Record 27 of Set 11 | mbini
# Processing Record 28 of Set 11 | bayir
# Processing Record 29 of Set 11 | umm kaddadah
# Processing Record 30 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 31 of Set 11 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 32 of Set 11 | aksu
# Processing Record 33 of Set 11 | pandamatenga
# Processing Record 34 of Set 11 | koygorodok
# Processing Record 35 of Set 11 | kunya
# Processing Record 36 of Set 11 | vuktyl
# Processing Record 37 of Set 11 | buraydah
# Processing Record 38 of Set 11 | atar
# Processing Record 39 of Set 11 | santa luzia
# Processing Record 40 of Set 11 | mattawa
# Processing Record 41 of Set 11 | lieksa
# Processing Record 42 of Set 11 | aleksandrov gay
# Processing Record 43 of Set 11 | kabinda
# Processing Record 44 of Set 11 | laives
# Processing Record 45 of Set 11 | krosno
# Processing Record 46 of Set 11 | burjuc
# Processing Record 47 of Set 11 | san ramon
# Processing Record 48 of Set 11 | le vauclin
# Processing Record 49 of Set 11 | puerto baquerizo moreno
# Processing Record 50 of Set 11 | san carlos del zulia
# Processing Record 1 of Set 12 | caucaia
# Processing Record 2 of Set 12 | varginha
# Processing Record 3 of Set 12 | mbandaka
# Processing Record 4 of Set 12 | wamba
# Processing Record 5 of Set 12 | ormstown
# Processing Record 6 of Set 12 | bowmore
# Processing Record 7 of Set 12 | goderich
# Processing Record 8 of Set 12 | riachao das neves
# Processing Record 9 of Set 12 | oum hadjer
# Processing Record 10 of Set 12 | bara
# Processing Record 11 of Set 12 | de aar
# Processing Record 12 of Set 12 | san jose
# Processing Record 13 of Set 12 | mazagao
# Processing Record 14 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 12 | derzhavinsk
# Processing Record 16 of Set 12 | farah
# Processing Record 17 of Set 12 | ponta delgada
# Processing Record 18 of Set 12 | belyy yar
# Processing Record 19 of Set 12 | chillicothe
# Processing Record 20 of Set 12 | saryozek
# Processing Record 21 of Set 12 | alta
# Processing Record 22 of Set 12 | petropavlovka
# Processing Record 23 of Set 12 | keti bandar
# Processing Record 24 of Set 12 | sakaraha
# Processing Record 25 of Set 12 | meulaboh
# Processing Record 26 of Set 12 | mariental
# Processing Record 27 of Set 12 | fajardo
# Processing Record 28 of Set 12 | luanda
# Processing Record 29 of Set 12 | kirkuk
# Processing Record 30 of Set 12 | gazli
# Processing Record 31 of Set 12 | sorland
# Processing Record 32 of Set 12 | bouna
# Processing Record 33 of Set 12 | shache
# Processing Record 34 of Set 12 | jutai
# Processing Record 35 of Set 12 | turukhansk
# Processing Record 36 of Set 12 | gidam
# Processing Record 37 of Set 12 | honningsvag
# Processing Record 38 of Set 12 | pemba
# Processing Record 39 of Set 12 | duki
# Processing Record 40 of Set 12 | venezuela
# Processing Record 41 of Set 12 | sao jose da coroa grande
# Processing Record 42 of Set 12 | thinadhoo
# Processing Record 43 of Set 12 | lovozero
# Processing Record 44 of Set 12 | isabela
# Processing Record 45 of Set 12 | aksakovo
# Processing Record 46 of Set 12 | moen
# Processing Record 47 of Set 12 | nurota
# Processing Record 48 of Set 12 | amalapuram
# Processing Record 49 of Set 12 | awbari
# Processing Record 50 of Set 12 | maniitsoq
# Processing Record 1 of Set 13 | sinnamary
# Processing Record 2 of Set 13 | mangan
# Processing Record 3 of Set 13 | mgandu
# Processing Record 4 of Set 13 | pavino
# Processing Record 5 of Set 13 | aswan
# Processing Record 6 of Set 13 | burica
# City not found. Skipping...
# Processing Record 7 of Set 13 | boa vista
# Processing Record 8 of Set 13 | sisimiut
# Processing Record 9 of Set 13 | ariquemes
# Processing Record 10 of Set 13 | medvezhyegorsk
# Processing Record 11 of Set 13 | hobe sound
# Processing Record 12 of Set 13 | presidencia roque saenz pena
# Processing Record 13 of Set 13 | dinard
# Processing Record 14 of Set 13 | narsaq
# Processing Record 15 of Set 13 | smiltene
# Processing Record 16 of Set 13 | locri
# Processing Record 17 of Set 13 | sharan
# Processing Record 18 of Set 13 | zambezi
# Processing Record 19 of Set 13 | fomboni
# Processing Record 20 of Set 13 | okahandja
# Processing Record 21 of Set 13 | yarim
# Processing Record 22 of Set 13 | kharp
# Processing Record 23 of Set 13 | ugoofaaru
# Processing Record 24 of Set 13 | sept-iles
# Processing Record 25 of Set 13 | les cayes
# Processing Record 26 of Set 13 | gornopravdinsk
# Processing Record 27 of Set 13 | santa maria
# Processing Record 28 of Set 13 | leshukonskoye
# Processing Record 29 of Set 13 | kuminskiy
# Processing Record 30 of Set 13 | villarrica
# Processing Record 31 of Set 13 | salinopolis
# Processing Record 32 of Set 13 | bingol
# Processing Record 33 of Set 13 | ayagoz
# Processing Record 34 of Set 13 | rawson
# Processing Record 35 of Set 13 | savelugu
# Processing Record 36 of Set 13 | dakoro
# Processing Record 37 of Set 13 | damaturu
# Processing Record 38 of Set 13 | camocim
# Processing Record 39 of Set 13 | yambio
# Processing Record 40 of Set 13 | sarti
# Processing Record 41 of Set 13 | crossville
# Processing Record 42 of Set 13 | acoyapa
# Processing Record 43 of Set 13 | farso
# Processing Record 44 of Set 13 | quebo
# Processing Record 45 of Set 13 | kharan
# Processing Record 46 of Set 13 | arona
# Processing Record 47 of Set 13 | mizdah
# Processing Record 48 of Set 13 | arrifes
# Processing Record 49 of Set 13 | kyzyl-suu
# Processing Record 50 of Set 13 | semnan
# Processing Record 1 of Set 14 | kaardi
# City not found. Skipping...
# Processing Record 2 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 14 | yabrud
# Processing Record 4 of Set 14 | cozumel
# Processing Record 5 of Set 14 | cacoal
# Processing Record 6 of Set 14 | ayolas
# Processing Record 7 of Set 14 | kochevo
# Processing Record 8 of Set 14 | arroio grande
# Processing Record 9 of Set 14 | ponnani
# Processing Record 10 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 11 of Set 14 | turtkul
# City not found. Skipping...
# Processing Record 12 of Set 14 | cassilandia
# Processing Record 13 of Set 14 | amapa
# Processing Record 14 of Set 14 | faya
# Processing Record 15 of Set 14 | alakurtti
# Processing Record 16 of Set 14 | akhtanizovskaya
# Processing Record 17 of Set 14 | khartoum
# Processing Record 18 of Set 14 | kegums
# Processing Record 19 of Set 14 | mandera
# Processing Record 20 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 21 of Set 14 | grand-bourg
# Processing Record 22 of Set 14 | shelburne
# Processing Record 23 of Set 14 | pen
# Processing Record 24 of Set 14 | upata
# Processing Record 25 of Set 14 | korla
# Processing Record 26 of Set 14 | koungou
# Processing Record 27 of Set 14 | puerto del rosario
# Processing Record 28 of Set 14 | bandar-e lengeh
# Processing Record 29 of Set 14 | mbanza-ngungu
# Processing Record 30 of Set 14 | novoagansk
# Processing Record 31 of Set 14 | pichayevo
# Processing Record 32 of Set 14 | cascais
# Processing Record 33 of Set 14 | yining
# Processing Record 34 of Set 14 | cervo
# Processing Record 35 of Set 14 | skvyra
# Processing Record 36 of Set 14 | abnub
# Processing Record 37 of Set 14 | terra santa
# Processing Record 38 of Set 14 | gorele
# Processing Record 39 of Set 14 | aasiaat
# Processing Record 40 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 41 of Set 14 | tawnat
# City not found. Skipping...
# Processing Record 42 of Set 14 | antofagasta
# Processing Record 43 of Set 14 | vallenar
# Processing Record 44 of Set 14 | colomi
# Processing Record 45 of Set 14 | longavi
# Processing Record 46 of Set 14 | bhanpuri
# Processing Record 47 of Set 14 | ekibastuz
# Processing Record 48 of Set 14 | atlantic city
# Processing Record 49 of Set 14 | taguatinga
# Processing Record 50 of Set 14 | qandahar
# City not found. Skipping...
# Processing Record 1 of Set 15 | tambura
# Processing Record 2 of Set 15 | qaqortoq
# Processing Record 3 of Set 15 | narva-joesuu
# Processing Record 4 of Set 15 | atasu
# Processing Record 5 of Set 15 | baijiantan
# Processing Record 6 of Set 15 | centralina
# Processing Record 7 of Set 15 | pietarsaari
# Processing Record 8 of Set 15 | salinas
# Processing Record 9 of Set 15 | bubaque
# Processing Record 10 of Set 15 | vestmanna
# Processing Record 11 of Set 15 | xai-xai
# Processing Record 12 of Set 15 | usinsk
# Processing Record 13 of Set 15 | bulaevo
# Processing Record 14 of Set 15 | shikarpur
# Processing Record 15 of Set 15 | mankera
# Processing Record 16 of Set 15 | tremembe
# Processing Record 17 of Set 15 | manama
# Processing Record 18 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 19 of Set 15 | lake city
# Processing Record 20 of Set 15 | aripuana
# Processing Record 21 of Set 15 | anar darreh
# City not found. Skipping...
# Processing Record 22 of Set 15 | pedernales
# Processing Record 23 of Set 15 | morlaix
# Processing Record 24 of Set 15 | nieuw amsterdam
# Processing Record 25 of Set 15 | dakar
# Processing Record 26 of Set 15 | detva
# Processing Record 27 of Set 15 | mancio lima
# Processing Record 28 of Set 15 | uruguaiana
# Processing Record 29 of Set 15 | azul
# Processing Record 30 of Set 15 | talara
# Processing Record 31 of Set 15 | verkhnyaya inta
# Processing Record 32 of Set 15 | puerto ayora
# Processing Record 33 of Set 15 | tombouctou
# Processing Record 34 of Set 15 | conceicao do coite
# Processing Record 35 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 36 of Set 15 | karwar
# Processing Record 37 of Set 15 | nouakchott
# Processing Record 38 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 39 of Set 15 | nsanje
# Processing Record 40 of Set 15 | banepa
# Processing Record 41 of Set 15 | bat khela
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd

# %%
city_data_df=pd.DataFrame(city_data)

# %%
city_data_df
# Out:
#              City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0    Longyearbyen  78.2186  15.6401     46.24        76          75
# 1            Mitu   1.1983 -70.1733     70.75       100         100
# 2     Port Alfred -33.5906  26.8910     58.39        71           0
# 3        Chingola -12.5290  27.8838     59.86        62          60
# 4           Limbe   4.0242   9.2149     76.10        84          70
# ..            ...      ...      ...       ...       ...         ...
# 684        Karwar  14.8000  74.1333     78.24        88          96
# 685    Nouakchott  18.0858 -15.9785     82.33        71          23
# 686        Nsanje -16.9200  35.2620     65.97        65          88
# 687        Banepa  27.6298  85.5214     73.72        94          75
# 688     Bat Khela  34.6167  71.9714     90.16        41           7
#
#      Wind Speed      Description                 Date
# 0          5.75    broken clouds  2021-07-24 17:02:42
# 1          0.27  overcast clouds  2021-07-24 17:10:13
# 2         22.12        clear sky  2021-07-24 17:02:43
# 3         13.04    broken clouds  2021-07-24 17:02:43
# 4         11.32       light rain  2021-07-24 17:10:14
# ..          ...              ...                  ...
# 684       12.37  overcast clouds  2021-07-24 17:06:20
# 685       12.12       few clouds  2021-07-24 17:05:22
# 686        6.98  overcast clouds  2021-07-24 17:06:21
# 687        3.44     thunderstorm  2021-07-24 17:06:21
# 688        4.41        clear sky  2021-07-24 17:06:22
#
# [689 rows x 9 columns]

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
